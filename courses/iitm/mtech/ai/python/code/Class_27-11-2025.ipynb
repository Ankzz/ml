# %%
import logging

# %%
logger = logging.getLogger()

logger.info("Info Message")

logger.warning("Warning Message")

# %%
import sys
import logging

logging.lastResort = None
logger1 = logging.getLogger("example")
logger1.propagate = False

logger1.info("Info message")
logger1.warning("Warning message")
# Out:
# Warning message

# %%
import logging

logger3 = logging.getLogger("example17")
# logger2.addHandler(logging.StreamHandler(stream=sys.stdout))
logger3.propagate = False

logger3.debug("Debug message")
logger3.info("Info message")
logger3.warning("Warning message")
logger3.error("Error message")
logger3.critical("Critical message")

try:
    raise ValueError("Value Error")
except ValueError:
    logger3.exception("Exception message")
# Out:
# Warning message
# Warning message
# Error message
# Error message
# Critical message
# Critical message
# Exception message
# Traceback (most recent call last):
#   File "C:\Users\ankit\AppData\Local\Temp\ipykernel_22736\3666535557.py", line 14, in <module>
#     raise ValueError("Value Error")
# ValueError: Value Error
# Exception message
# Traceback (most recent call last):
#   File "C:\Users\ankit\AppData\Local\Temp\ipykernel_22736\3666535557.py", line 14, in <module>
#     raise ValueError("Value Error")
# ValueError: Value Error

# %%
import logging

logging.basicConfig()

logger4 = logging.getLogger("example")

logger4.addHandler(logging.FileHandler())
