# %% [markdown]
# K-Mean Algorithm
#
# Application:
# * Customer Behavior
# * Disease propagation
# * Insurance
#
# Step 1: Standardize data
# Step 2: Define value of k
# Step 3: Set k random

# %%
import numpy as np
from sklearn.cluster import KMeans

KMeans()
