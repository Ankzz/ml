# %% [markdown]
# CLuster Analysis
# - K Means
# - Knee Method
# - Hierarchical Clustering
#   - Dendogram Clustering
#   - Agglomerative Clustering
#   - Divisive Clustering
# Quality of Clusters
# - Purity
# - Entropy

# %% [markdown]
# K-Means Clustering
#
# - Step 0 - Choose k
# - Step 1 - Choose k cluster centers - Randomly
# - Step 2 - Identify and Assign instances to Clusters
#             - Usually based on Euclidean distance
# - Step 3 - Computer centroid to Cluster
# - Step 4 - Make centroids as Cluster centers, Iterate back tp Step-2
