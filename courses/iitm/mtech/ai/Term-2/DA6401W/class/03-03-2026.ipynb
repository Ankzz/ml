# %% [markdown]
# Conjugate Descent
# Nesterov Optimization
# Regularization
# LASSO
# Generalization Performance
# Data Augmentation
#  - Noise Injection
#  - Label smoothing
#  - Unsupervised Learning:
#    - Learn data distribution and sample from data distribution
#    - Bootstrapping through autoencoders
